# %% [markdown]
# # Assignment
#
# The assignment will require you to complete cells, create new ones, and move around some cells. You need to familiarize yourself with the Jupyter notebook interface. You can find a tutorial [here](https://www.dataquest.io/blog/jupyter-notebook-tutorial/).

# %% [markdown]
# ---

# %% [markdown]
# # [EXERCISE 1]
#
# ## Francisco Castro fcastro1@mail.austral.edu.ar
#
# ![apolojupyter.jpg](attachment:a140447b-33d7-4dcc-bfbc-b063b81f22e0.jpg)
# Mi perro Apolo durmiendo.

# %% [markdown]
# # [EXERCISE 5]

# %%
a = 3
b = 7

# %% [markdown]
# ### Suma

# %%
a + b
# Out:
# 10

# %% [markdown]
# ### Resta

# %%
a - b
# Out:
# -4

# %% [markdown]
# ### Multiplicación

# %%
a * b
# Out:
# 21

# %% [markdown]
# ### División

# %%
a / b
# Out:
# 0.42857142857142855
